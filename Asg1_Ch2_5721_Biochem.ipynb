# %% [markdown]
# <a href="https://colab.research.google.com/github/mpfoster/Biochem5721/blob/master/Asg1_Ch2_5721_Biochem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 1, Biochem 5721 AU 2020
# Chapter 2 problems: 1, 6, 7, 9, 11, 12, 20, 27, 28, 29, 35
# (Feel free to insert additional `Code` cells where useful to faciliate calculations or clarity. That is, you could answer multiple part questions in a single code cell, one code cell per part, or many code cells per part)
#
# ## Q2.1
# a. A hiker caught in a rainstorm absorbs 1.00 L of water in her clothing. If it is windy so that the water evaporates quickly at 20°C, how much heat is required for this process?

# %%
""" 
Plase your answer in this cell; be sure to describe the calculation and specify units.
use formatted printing for output e.g., 
print("Evaporating 1L of water would consume %5.2f J of heat", % q)
"""
# This is an in-line comment

# %% [markdown]
# b. If all this heat is removed from the hiker (no significant heat was generated by metabolism during this time), what drop in body temperature would the hiker experience? The clothed hiker weighs 60 kg, and you can approximate the heat capacity of hiker and clothes as equal to that of water. (Moral: stay out of the wind if you get your clothes wet.)

# %%
# answer; draining that much heat would cause how much of a temperature drop?

# %% [markdown]
# c. How many grams of sucrose would the hiker have to metabolize (quickly) to replace the heat of evaporating 1.00 L of water so that her temperature would not change? You can use the enthalpy of reaction at 25°C; the sucrose (s) reacts with oxygen (g) to give carbon dioxide (g) and water (l).

# %%
# answer; metabolizing how much glucose would compensate for that evaporation

# %% [markdown]
# ---
# ## Q2.6
# Calculate the heat (in joules) absorbed by the system for each of the following examples (the system is given in italics). Specify the sign of the heat.
# a. 100 g of liquid water is heated from 0 degree(s) C to 100°C at 1 bar.

# %% [markdown]
# b. 100 g of liquid water is heated from 0 degree(s) C to 100°C at 0.01 bar.

# %% [markdown]
# c. 100 g of liquid water is evaporated to steam at 100°C at 1 bar.

# %% [markdown]
# ---
# ## Q2.7
# One mole of an ideal gas initially at 27°C and 1 bar pressure is heated and allowed to expand reversibly at constant pressure until the final temperature is 327°C. For this gas, C v,m == 2.5R, constant over the temperature range.
#
# a.	Calculate the work w done on the gas in this expansion.
#
# b.	What are dU and dH for the process?
#
# c.	What is the amount of heat q absorbed by the gas?

# %% [markdown]
# ---
# ## Q2.8
# _Staphylococcus aureus_ is a spherical cell approximately 1.0 µm in diameter. Assuming it is almost entirely water with a density of 1 g/mL, compute
#
# a.	The mass of the bacterium in kg
#
# b.	The mass of the bacterium in kD
#
# c.	The number of water molecules it contains
#
# d.	How many _S. aureus_ in a row would it take to circle the Earth? (Earth radius at the equator is 6378.1 km.)
#
# e.	The surface area in m<sup>2</sup>
#
# f.	The number of phospholipid molecules in its plasma membrane, assuming each lipid molecule has an area of 0.50 nm<sup>2</sup>

# %% [markdown]
# ---
# ## Q2.9
# For the following processes, calculate the indicated quanti­ties for a system consisting of 1 mol of N<sub>2</sub> gas. Assume ideal gas behavior.
#
# a.	The gas, initially at 10 bar, is expanded tenfold in volume against a constant external pressure of 1 bar, all at 298 K. Calculate _q, w_, $\Delta$U and $\Delta$H for the gas.
#
# b.	After the expansion in part (a), the volume is fixed, and heat is added until the temperature reaches 373 K. Calculate _q, w_, $\Delta$U and $\Delta$H.
#
# c.	What will be the pressure of the gas at the end of the process in part (b)?
#
# d.	If the gas at 373 K is next allowed to expand against 1 bar pressure under adiabatic conditions (no heat transferred), will the final temperature be higher, remain unchanged, or be lower than 373 K? Explain your answer.

# %% [markdown]
# ---
# ## Q2.11
#
# One mole of liquid water at 100°C is heated until the liquid is converted entirely to vapor at 100°C and 1 bar pressure.  Calculate _q_, _w_, $\Delta$U and $\Delta$H for each of the following:
#
# a. The vaporization is carried out in a cylinder where the external pressure on the piston is maintained at  1 bar
#
# b. The cylinder is first expanded against a vacuum ($p_{ext} = 0$) to the same volume in part (a), and then sufficient heat is added to vaporize the liquid completely at 1 bar of pressure.

# %% [markdown]
# ---
# ## Q2.12
# An ice cube weighing 18 g is removed from a freezer, where it has been at -20°C.
#
# a.	How much heat is required to warm it to 0°C without melting it?
#
# b.	How much additional heat is required to melt it to liquid water at 0°C?
#
# c.	Suppose the ice cube was placed initially in a 180 g sample of liquid water at +20°C in an insulated ( ther­mally isolated) container. Describe the final state when the system has reached equilibrium.

# %% [markdown]
# ---
# ## Q2.20
# One hundred grams of liquid H<sub>2</sub>0 at 55°C is mixed with 10 g of ice at -10°C. The pressure is kept constant, and no heat is allowed to leave the system. The process is adiabatic. Calculate the final temperature for the system.

# %% [markdown]
# ---
# ## Q2.28
# A good yield of photosynthesis for agricultural crops in bright sunlight is 20 kg of carbohydrate (for example, sucrose) per hectare per hour. (1 hectare == 104 m<sup>2</sup>). The net reaction for sucrose formation in photosynthesis can be written:
#
# $$12 CO_2(g) + 11 H_20(l) \rightarrow C_{12}H_{22}0_{11}(s) + 12 O_2(g)$$
#
# a.	Use standard enthalpies of formation to calculate D /f0 for the production of 1 mol of sucrose at 25°C by the reaction above.

# %% [markdown]
# b.	Calculate the energy equivalent of photosynthesis that yields 20 kg of sucrose (hectare<sup>-1</sup> h<sup>-1</sup>).

# %% [markdown]
# c.	Bright sunlight corresponds to radiation incident on the surface of Earth at about 1 kW m<sup>-2</sup>. What percentage of this energy can be "stored" as carbohydrate in photosynthesis?

# %% [markdown]
# ---
# ## Q2..29
# a.	Calculate the enthalpy change on burning 1 g of H<sub>2</sub>(g) to H<sub>2</sub>O(l) at 25°C and 1 bar.
# b.	Calculate the enthalpy change on burning 1 g of n-octane
# (g)	to CO<sub>2</sub>(g) and H<sub>2</sub>O(l) at 25°C and 1 bar.
# c.	Compare H<sub>2</sub>O(g) and n-octane(g) in terms of joules of heat available per gram.

# %% [markdown]
# ---
# ## Q2.35
# <img align="right" src="https://raw.githubusercontent.com/mpfoster/Biochem5721/master/images/02_Pg54_UnFigure_1.jpg" width="200"/><img  align="right" src="https://raw.githubusercontent.com/mpfoster/Biochem5721/master/images/02_Pg54_UnFigure_2.jpg" width="200"/>
#
# The standard enthalpies at 25°C of gaseous trans-2-butene and cis-2-butene are -11.1 and -7.0 kJ/mo1, respectively. In the cis compound the relatively bulky methyl groups interact repulsively with one another because they are both constrained to remain on the same side of the molecule. (There is no rotation about the C-C bond.) Calculate the thermodynamic enthalpy attributable to this steric repulsion in the cis compound relative to the trans where the methyl groups are on the opposite sides of the molecule. This is an example of how detailed molecular information can be deduced from thermochemical data.
