# %% [markdown]
# <a href="https://colab.research.google.com/github/mpfoster/Biochem5721/blob/master/HW0_Biochem_5721_AU_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Biochem 5721 AU 2020
# ## Assignment 0
#
# This is a Markdown cell. [Markdown](https://guides.github.com/features/mastering-markdown/) is an easy-to-type formatting language that is interpreted into HTML to generate nice formatting withought having to learn and type html code, like `<i>`*for italics*`</i>`.
#
# Create your first Jupyter notebooks (on [http://colab.google.com](http://colab.google.com) ). This will be easiest if you already have GMail accounts. Include:
# 1. A markdown cell with:
#   * a heading
#   * a subheading
#   * a 2-column table with:
#     * your name
#     - your recitation section
#     - your name.#
#     * a sentence
#   * a numbered list
# 1. A code cell with:
#   * a comment
#   * a mathematical operation
#   * a formatted print statement
#
# (Use this sample notebook as a guide)
#
#
# # This is a heading
# ## This is a subheading
#
# I can be **bold**, __bolded__, *italics*, _italicized_,
#
# Check out the [markdown cheat-sheet](https://www.markdownguide.org/cheat-sheet) for formatting lists

# %%
# answer in this cell; be sure to describe the calculation and specify units.
# use formatted printing for output e.g., 
# print("Evaporating 1L of water would consume %5.2f J of heat", % q)

# %% [markdown]
# b. If all this heat is removed from the hiker (no significant heat was generated by metabolism during this time), what drop in body temperature would the hiker experience? The clothed hiker weighs 60 kg, and you can approximate the heat capacity of hiker and clothes as equal to that of water. (Moral: stay out of the wind if you get your clothes wet.)

# %%
# answer; draining that much heat would cause how much of a temperature drop?

# %% [markdown]
# c. How many grams of sucrose would the hiker have to metabolize (quickly) to replace the heat of evaporating 1.00 L of water so that her temperature would not change? You can use the enthalpy of reaction at 25°C; the sucrose (s) reacts with oxygen (g) to give carbon dioxide (g) and water (l).

# %%
# answer; metabolizing how much glucose would compensate for that evaporation

# %% [markdown]
# d.
